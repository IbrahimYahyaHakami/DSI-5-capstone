# %%
# imports libraries
import pandas as pd
import numpy as np
# %matplotlib inline

# Load specific forecasting tools

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from fbprophet import Prophet
from statsmodels.tsa.stattools import adfuller

# Load specific evaluation tools
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from sklearn.metrics import r2_score

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import time
from datetime import datetime

# Lines below are just to ignore warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
# read dataset and show the first 5 rows
df = pd.read_csv('../dataset/full_COA.csv.' , index_col='Time',parse_dates=True)
df.head()
# Out:
#                         COA   temp  year  quarter  month  day  weekday_0  \
# Time
# 2012-01-01 01:00:00  5986.0  13.98  2012        1      1    1          0
# 2012-01-01 02:00:00  5547.0  11.98  2012        1      1    1          0
# 2012-01-01 03:00:00  5233.0  11.98  2012        1      1    1          0
# 2012-01-01 04:00:00  5150.0  11.98  2012        1      1    1          0
# 2012-01-01 05:00:00  5235.0  11.98  2012        1      1    1          0
#
#                      weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# Time
# 2012-01-01 01:00:00          0          0          0          0          0
# 2012-01-01 02:00:00          0          0          0          0          0
# 2012-01-01 03:00:00          0          0          0          0          0
# 2012-01-01 04:00:00          0          0          0          0          0
# 2012-01-01 05:00:00          0          0          0          0          0
#
#                      weekday_6
# Time
# 2012-01-01 01:00:00          1
# 2012-01-01 02:00:00          1
# 2012-01-01 03:00:00          1
# 2012-01-01 04:00:00          1
# 2012-01-01 05:00:00          1

# %%
# show last five rows
df.tail()
# Out:
#                         COA   temp  year  quarter  month  day  weekday_0  \
# Time
# 2017-12-31 19:00:00  9495.0  18.98  2017        4     12   31          0
# 2017-12-31 20:00:00  9365.0  16.98  2017        4     12   31          0
# 2017-12-31 21:00:00  9250.0  15.98  2017        4     12   31          0
# 2017-12-31 22:00:00  8931.0  14.98  2017        4     12   31          0
# 2017-12-31 23:00:00  8679.0  12.98  2017        4     12   31          0
#
#                      weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# Time
# 2017-12-31 19:00:00          0          0          0          0          0
# 2017-12-31 20:00:00          0          0          0          0          0
# 2017-12-31 21:00:00          0          0          0          0          0
# 2017-12-31 22:00:00          0          0          0          0          0
# 2017-12-31 23:00:00          0          0          0          0          0
#
#                      weekday_6
# Time
# 2017-12-31 19:00:00          1
# 2017-12-31 20:00:00          1
# 2017-12-31 21:00:00          1
# 2017-12-31 22:00:00          1
# 2017-12-31 23:00:00          1

# %%
# get only megawaats and tempreture
df_l = df[['COA', 'temp']]

# %%
# show length of dataframe
len(df_l)
# Out:
# 52607

# %%
# assain frequebcy to hourly
df_l.index.freq = '1H'

# %%
# resample data to daily data
df_d = df_l.resample(rule = 'D').mean()

# %%
# assain frequebcy to daily
df_d.index.freq = 'D'

# %%
# plotting daily data set
pd.plotting.register_matplotlib_converters() # this code used to resolve some failure prophet have with pandas
df_d.COA.plot(figsize=(15,5)).autoscale(axis='x',tight=True)

# %%
# seasonal decompose for megawatts 
seasonal_decompose(df_d.COA , freq=365).plot();

# %%
# autocorrelation plot
plot_acf(df_d.COA , lags=20);

# %%
# partial autocorrelaton plot
plot_pacf(df_d.COA , lags=20);

# %%
# define a function to do the Dickey-Fuller Test

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
# Dickey-Fuller Test for megawatts
adf_test(df_d.COA)
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        -3.232169
# p-value                    0.018197
# # lags used               23.000000
# # observations          2168.000000
# critical value (1%)       -3.433370
# critical value (5%)       -2.862874
# critical value (10%)      -2.567480
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
# reset index to prepare data frame for prophet
df_d = df_d.reset_index()

# %%
# feature engineering 
df_d['year'] = df_d['Time'].apply(lambda x: x.year)
df_d['quarter'] = df_d['Time'].apply(lambda x: x.quarter)
df_d['month'] = df_d['Time'].apply(lambda x: x.month)
df_d['day'] = df_d['Time'].apply(lambda x: x.day)
# df_l=df_l.loc[:,['Time','COA', 'year','quarter','month','day']]
df_d.sort_values('Time', inplace=True, ascending=True)
# df = df.reset_index(drop=True)
df_d["weekday"]=df_d.apply(lambda row: row["Time"].weekday(),axis=1)
df_d["weekday"] = df_d["weekday"].astype(str)
df_d = pd.get_dummies(df_d)

# %%
# rename columns to prepare it for prophet
df_d = df_d.rename(columns = {'Time':'ds',
                      'COA':'y'})

# %%
# define a length to split, split last year
l_split = len(df_d[df_d.ds >= '2017-01-01 00:00:00'])

# %%
# split by pre defined length
train = df_d.iloc[:(len(df_d)-l_split)]
test = df_d.iloc[(len(df_d)-l_split):]

# %%
# fitting the model with additional regressors
model = Prophet(seasonality_mode='multiplicative')
model.add_regressor('temp')
model.add_regressor('year')
model.add_regressor('quarter')
model.add_regressor('month')
model.add_regressor('day')
model.add_regressor('weekday_0')
model.add_regressor('weekday_1')
model.add_regressor('weekday_2')
model.add_regressor('weekday_3')
model.add_regressor('weekday_4')
model.add_regressor('weekday_5')
model.add_regressor('weekday_6')
model.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# make data frame to hold the prediction
future = model.make_future_dataframe(periods=365 , freq='D')

# %%
# make prediction on the data frame made 
forecast = model.predict(test.drop(columns= ['y']))

# %%
# check predictionn columns
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'day', 'day_lower', 'day_upper', 'extra_regressors_multiplicative',
#        'extra_regressors_multiplicative_lower',
#        'extra_regressors_multiplicative_upper', 'month', 'month_lower',
#        'month_upper', 'multiplicative_terms', 'multiplicative_terms_lower',
#        'multiplicative_terms_upper', 'quarter', 'quarter_lower',
#        'quarter_upper', 'temp', 'temp_lower', 'temp_upper', 'weekday_0',
#        'weekday_0_lower', 'weekday_0_upper', 'weekday_1', 'weekday_1_lower',
#        'weekday_1_upper', 'weekday_2', 'weekday_2_lower', 'weekday_2_upper',
#        'weekday_3', 'weekday_3_lower', 'weekday_3_upper', 'weekday_4',
#        'weekday_4_lower', 'weekday_4_upper', 'weekday_5', 'weekday_5_lower',
#        'weekday_5_upper', 'weekday_6', 'weekday_6_lower', 'weekday_6_upper',
#        'weekly', 'weekly_lower', 'weekly_upper', 'year', 'year_lower',
#        'year_upper', 'yearly', 'yearly_lower', 'yearly_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yhat'],
#       dtype='object')

# %%
# show last 5 rows of forecast
forecast.tail()
# Out:
#             ds         trend   yhat_lower   yhat_upper  trend_lower  \
# 360 2017-12-27  10101.019868  7195.718656  9012.259796  9693.776868
# 361 2017-12-28  10100.439622  7012.632382  8752.667545  9692.234169
# 362 2017-12-29  10099.859375  6621.099348  8418.097271  9690.786894
# 363 2017-12-30  10099.279128  7038.726752  8847.007504  9689.002092
# 364 2017-12-31  10098.698882  7391.278665  9195.971235  9687.540677
#
#       trend_upper       day  day_lower  day_upper  \
# 360  10471.620758  0.000751   0.000751   0.000751
# 361  10471.754427  0.000818   0.000818   0.000818
# 362  10471.919131  0.000885   0.000885   0.000885
# 363  10473.222048  0.000952   0.000952   0.000952
# 364  10474.992256  0.001018   0.001018   0.001018
#
#      extra_regressors_multiplicative     ...           year  year_lower  \
# 360                        -0.006161     ...       0.010071    0.010071
# 361                        -0.005115     ...       0.010071    0.010071
# 362                        -0.012101     ...       0.010071    0.010071
# 363                         0.000619     ...       0.010071    0.010071
# 364                         0.014893     ...       0.010071    0.010071
#
#      year_upper    yearly  yearly_lower  yearly_upper  additive_terms  \
# 360    0.010071 -0.206971     -0.206971     -0.206971             0.0
# 361    0.010071 -0.206466     -0.206466     -0.206466             0.0
# 362    0.010071 -0.206008     -0.206008     -0.206008             0.0
# 363    0.010071 -0.205565     -0.205565     -0.205565             0.0
# 364    0.010071 -0.205108     -0.205108     -0.205108             0.0
#
#      additive_terms_lower  additive_terms_upper         yhat
# 360                   0.0                   0.0  8044.297755
# 361                   0.0                   0.0  7945.010430
# 362                   0.0                   0.0  7470.798152
# 363                   0.0                   0.0  7967.125959
# 364                   0.0                   0.0  8314.841610
#
# [5 rows x 58 columns]

# %%
# plotting forcast
model.plot(forecast);

# %%
# make a seperate data set for prediction only
predictions = forecast[['ds','yhat']][forecast.ds >='2017']

# %%
# set time as index
predictions = predictions.set_index('ds')
test = test.set_index('ds')

# %%
# plot test vs prediction
test.y.plot(legend=True)
predictions.yhat.plot(figsize=(12,5) , legend=True)

# %%
# calculate rmse
rmse(test.y,predictions.yhat)
# Out:
# 1232.2678280659034

# %%
# calculate r2 score
r2_score(test.y , predictions.yhat)
# Out:
# 0.899361138587255
